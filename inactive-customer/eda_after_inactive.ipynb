# %%
from common.ultis import eda

# %%
eda.eda_after(data="data\\fixed_data_inactive.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118846 entries, 0 to 118845
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   AGE                        118846 non-null  float64
#  1   NAV_BQ_12M                 118846 non-null  float64
#  2   TODAY_NAV                  118846 non-null  float64
#  3   CASH_IN                    118846 non-null  float64
#  4   CASH_OUT                   118846 non-null  float64
#  5   TRADING_COUNT_1M           118846 non-null  float64
#  6   TRADING_COUNT_2M           118846 non-null  float64
#  7   TRADING_COUNT_3M           118846 non-null  float64
#  8   TRADING_COUNT_6M           118846 non-null  float64
#  9   GTGD_6M                    118846 non-null  float64
#  10  VQGD_6M                    118846 non-null  float64
#  11  PROFIT_LOSS_6M             118846 non-null  float64
#  12  PROFIT_LOSS_PERCENTAGE_6M  118846 non-null  float64
# ...
