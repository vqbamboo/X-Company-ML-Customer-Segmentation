# %%
from common.ultis import visualization

# Gọi hàm visualization_2d
visualization.visualization_2d(data = 'data/data_with_cluster.csv')

# %%
from common.ultis import visualization

# Gọi hàm visualization_3d
visualization.visualization_3d(data = 'data/data_with_cluster.csv')
