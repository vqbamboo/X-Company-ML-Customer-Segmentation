# %%
from common.ultis import eda
import pandas as pd

# %%
eda.eda_before(data="data\\data_inactive.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118846 entries, 0 to 118845
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   #_x                        118846 non-null  int64
#  1   MASTER_ACCOUNT             118846 non-null  object
#  2   CHANNEL                    118846 non-null  object
#  3   AGE                        118391 non-null  float64
#  4   NAV_BQ_12M                 118846 non-null  float64
#  5   TODAY_NAV                  118846 non-null  int64
#  6   CASH_IN                    14101 non-null   float64
#  7   CASH_OUT                   102198 non-null  float64
#  8   TRADING_COUNT_1M           118846 non-null  int64
#  9   TRADING_COUNT_2M           118846 non-null  int64
#  10  TRADING_COUNT_3M           118846 non-null  int64
#  11  TRADING_COUNT_6M           118846 non-null  int64
#  12  GTGD_6M                    118846 non-null  int64
# ...

# %%
df = pd.read_csv("data\\data_inactive.csv")

# %%
# in giá trị nhỏ nhất cột age
print(df["AGE"].min())
# Out:
# -7974.0
