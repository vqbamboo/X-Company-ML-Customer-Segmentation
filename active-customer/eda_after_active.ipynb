# %%
from common.ultis import eda

# %%
eda.eda_after(data="data\\fixed_data_active.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102877 entries, 0 to 102876
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   AGE                     102877 non-null  float64
#  1   NAV_WEIGHT              102877 non-null  float64
#  2   NAV_BQ_12M              102877 non-null  float64
#  3   CASH_IN_6M              102877 non-null  float64
#  4   CASH_OUT_6M             102877 non-null  float64
#  5   TRADING_COUNT_1M        102877 non-null  float64
#  6   TRADING_COUNT_2M        102877 non-null  float64
#  7   TRADING_COUNT_3M        102877 non-null  float64
#  8   TRADING_COUNT_6M        102877 non-null  float64
#  9   GTGD_6M                 102877 non-null  float64
#  10  VQGD_6M                 102877 non-null  float64
#  11  PROFIT_LOSS             102877 non-null  float64
#  12  PROFIT_LOSS_PERCENTAGE  102877 non-null  float64
# ...
