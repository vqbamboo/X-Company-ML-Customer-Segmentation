# %%
from common.ultis import visualization

# Gọi hàm visualization_2d
visualization.visualization_2d(data = 'data_with_clusters.csv')

# %%
from common.ultis import visualization

# Gọi hàm visualization_3d
visualization.visualization_3d(data = 'data_with_clusters.csv')
# Out:
# C:\Users\BRAVO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\manifold\_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
