# %%
from common.ultis import eda

# %%
eda.eda_before(data="data_active.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102877 entries, 0 to 102876
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   #_x                     102877 non-null  int64
#  1   MASTER_ACCOUNT          102877 non-null  object
#  2   CHANNEL                 102877 non-null  object
#  3   AGE                     102669 non-null  float64
#  4   NAV_WEIGHT              102877 non-null  float64
#  5   NAV_BQ_12M              102877 non-null  float64
#  6   CASH_IN_6M              49588 non-null   float64
#  7   CASH_OUT_6M             55728 non-null   float64
#  8   TRADING_COUNT_1M        77064 non-null   float64
#  9   TRADING_COUNT_2M        77064 non-null   float64
#  10  TRADING_COUNT_3M        77064 non-null   float64
#  11  TRADING_COUNT_6M        77064 non-null   float64
#  12  GTGD_6M                 77064 non-null   float64
# ...
