# %%
from common.ultis import evaluation

# Đánh giá model đã được thực hiện ở code_model_active.py
evaluation.evaluation(data='data/data_with_cluster.csv', model_path='model/kmeans_model.pkl')
# Out:
# Silhouette Score: 0.23681069188971646
# Davies Bouldin Index: 1.7148850368563273
